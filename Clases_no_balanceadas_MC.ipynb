# %% [markdown]
# <a href="https://colab.research.google.com/github/Elmermd/Academia-IA/blob/main/Clases_no_balanceadas_MC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejemplo Clase no Balanceada

# %% [markdown]
# Caso donde queremos tener un sistema para predecir si un autobús llegará a tiempo a una determinada parada. En la gran mayoría de los casos los autobuses llegarán puntualmente. Los retrasos se deberán a factores imprevistos o externos como accidentes, manifestaciones o malas condiciones climáticas.
#
# Clase no balanceada, donde la mayoria de los datos serán llegadas a tiempo y los retrasos serán menores.

# %% [markdown]
# # Matriz de Confusión

# %% [markdown]
#  Una matriz de confusión es una herramienta que permite visualizar el desempeño de un algoritmo  de aprendizaje supervisado. Nos permite ver  qué tipos de aciertos y errores está teniendo nuestro modelo a la hora de pasar por el proceso de aprendizaje con los datos.
#
#  ## Estructura Básica
#  Vamos a conocer la estructura básica de una matriz de confusión (binaria), utilizando el ejemplo de identificar un correo electrónico como spam o no spam.
#
# - **Verdadero positivo (TP)** - El modelo predijo correctamente la clase positiva. Por ejemplo, identificar un correo electrónico como spam.
# - **Negativo verdadero (NT)** - El modelo predijo correctamente la clase negativa. Por ejemplo, identificar un correo electrónico normal como no spam.
# - **Falso positivo (FP)** - El modelo predijo incorrectamente la clase positiva. Por ejemplo, identificar un correo normal como spam.
# - **Falso negativo (FN)** - El modelo predijo incorrectamente la clase negativa. Por ejemplo, identificar un correo basura como un correo normal.
#
# ![MATRIZ-CONFUSION-400x358.png](data:image/png;base64,...)

# %% [markdown]
# ## Metricas
# ### Precisión
# La precisión mide el número total de positivos verdaderos dividido por el número total de positivos predichos.
#
# ![image.png](data:image/png;base64,...)
# ### Memoria/Sensibilidad
# El recuerdo/sensibilidad mide el número total de verdaderos positivos dividido por el número total de verdaderos positivos.
#
# ![image.png](data:image/png;base64,...)
# ### Especificidad
# La especificidad mide el número total de verdaderos negativos dividido por el número total de verdaderos negativos.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Referencias
# - https://www.datasource.ai/es/data-science-articles/comprension-de-la-matriz-de-confusion-y-como-implementarla-en-python
#
# - https://www.juanbarrios.com/la-matriz-de-confusion-y-sus-metricas/
#
# - https://www.datacamp.com/es/tutorial/what-is-a-confusion-matrix-in-machine-learning

# %% [markdown]
# # Ejemplo
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En donde:
# 1. VP = 412
# 2. VN = 2137
# 3. FP = 256
# 4. FN = 17

# %% [markdown]
# ![image.png](data:image/png;base64,...)
